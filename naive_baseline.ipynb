# %% [markdown]
# <a href="https://colab.research.google.com/github/zpsheldon/meg-neural-decoding/blob/main/naive_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports

# %%
# Install additional depdendencies
# %pip install -q lightning torchmetrics scikit-learn plotly ipywidgets pnpl

# Set up base path for dataset and related files (base_path is assumed to be set in the cells below!)
base_path = "./libribrain"
try:
    import google.colab  # This module is only available in Colab.
    in_colab = True
    base_path = "/content"  # This is the folder displayed in the Colab sidebar
except ImportError:
    in_colab = False
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.0 MB/s eta 0:00:00

# %%
from pnpl.datasets import LibriBrainSpeech
from torch.utils.data import DataLoader

# %% [markdown]
# ## Load data

# %%
num_books = 7
num_chapters = [9, 12, 12, 12, 15, 14, 14]

# %%
# Conditionally set num_workers to avoid multiprocessing issues (try increasing if performance is problematic)
num_workers = 2 if in_colab else 0

# For training, we'll use all sessions from Sherlock 1 to Sherlock 5
train_run_keys = [("0",str(i),f"Sherlock{j}","1") for j in range(1,5) for i in range(1, num_chapters[j-1])]
train_data = LibriBrainSpeech(
  data_path=f"{base_path}/data/",
  include_run_keys = train_run_keys,
  tmin=0.0,
  tmax=0.8,
  preload_files = True
)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=num_workers)
# Out:
# Downloading 3 files...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2801660784.py in <cell line: 0>()
#       4 # For training, we'll use all sessions from Sherlock 1 to Sherlock 5
#       5 train_run_keys = [("0",str(i),f"Sherlock{j}","1") for j in range(1,5) for i in range(1, num_chapters[j-1])]
# ----> 6 train_data = LibriBrainSpeech(
#       7   data_path=f"{base_path}/data/",
#       8   include_run_keys = train_run_keys,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/speech_dataset.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, oversample_silence_jitter, preload_files, stride, download)
#      97             Labels are arrays indicating speech (1) vs silence (0) for each timepoint in the sample.
#      98         """
# ---> 99         super().__init__(
#     100             data_path=data_path,
#     101             partition=partition,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, preload_files, preload_event_file, download)
#     157         # Preload files if requested BEFORE calling _get_sfreq which would trigger sequential downloads
#     158         if self.preload_files and self.download:
# --> 159             self.prefetch_files(get_event_files = self.preload_event_file)
#     160
#     161         # Now we can safely get sfreq as files are already downloading/downloaded
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in prefetch_files(self, get_event_files)
#     199             for future in futures:
#     200                 try:
# --> 201                     future.result()
#     202                 except Exception as e:
#     203                     print(f"Error downloading a file: {e}")
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-2801660784.py in <cell line: 0>()
#       4 # For training, we'll use all sessions from Sherlock 1 to Sherlock 5
#       5 train_run_keys = [("0",str(i),f"Sherlock{j}","1") for j in range(1,5) for i in range(1, num_chapters[j-1])]
# ----> 6 train_data = LibriBrainSpeech(
#       7   data_path=f"{base_path}/data/",
#       8   include_run_keys = train_run_keys,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/speech_dataset.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, oversample_silence_jitter, preload_files, stride, download)
#      97             Labels are arrays indicating speech (1) vs silence (0) for each timepoint in the sample.
#      98         """
# ---> 99         super().__init__(
#     100             data_path=data_path,
#     101             partition=partition,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, preload_files, preload_event_file, download)
#     157         # Preload files if requested BEFORE calling _get_sfreq which would trigger sequential downloads
#     158         if self.preload_files and self.download:
# --> 159             self.prefetch_files(get_event_files = self.preload_event_file)
#     160
#     161         # Now we can safely get sfreq as files are already downloading/downloaded
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in prefetch_files(self, get_event_files)
#     199             for future in futures:
#     200                 try:
# --> 201                     future.result()
#     202                 except Exception as e:
#     203                     print(f"Error downloading a file: {e}")
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-2801660784.py in <cell line: 0>()
#       4 # For training, we'll use all sessions from Sherlock 1 to Sherlock 5
#       5 train_run_keys = [("0",str(i),f"Sherlock{j}","1") for j in range(1,5) for i in range(1, num_chapters[j-1])]
# ----> 6 train_data = LibriBrainSpeech(
#       7   data_path=f"{base_path}/data/",
#       8   include_run_keys = train_run_keys,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/speech_dataset.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, oversample_silence_jitter, preload_files, stride, download)
#      97             Labels are arrays indicating speech (1) vs silence (0) for each timepoint in the sample.
#      98         """
# ---> 99         super().__init__(
#     100             data_path=data_path,
#     101             partition=partition,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, preload_files, preload_event_file, download)
#     157         # Preload files if requested BEFORE calling _get_sfreq which would trigger sequential downloads
#     158         if self.preload_files and self.download:
# --> 159             self.prefetch_files(get_event_files = self.preload_event_file)
#     160
#     161         # Now we can safely get sfreq as files are already downloading/downloaded
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in prefetch_files(self, get_event_files)
#     199             for future in futures:
#     200                 try:
# --> 201                     future.result()
#     202                 except Exception as e:
#     203                     print(f"Error downloading a file: {e}")
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-2801660784.py in <cell line: 0>()
#       4 # For training, we'll use all sessions from Sherlock 1 to Sherlock 5
#       5 train_run_keys = [("0",str(i),f"Sherlock{j}","1") for j in range(1,5) for i in range(1, num_chapters[j-1])]
# ----> 6 train_data = LibriBrainSpeech(
#       7   data_path=f"{base_path}/data/",
#       8   include_run_keys = train_run_keys,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/speech_dataset.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, oversample_silence_jitter, preload_files, stride, download)
#      97             Labels are arrays indicating speech (1) vs silence (0) for each timepoint in the sample.
#      98         """
# ---> 99         super().__init__(
#     100             data_path=data_path,
#     101             partition=partition,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, preload_files, preload_event_file, download)
#     157         # Preload files if requested BEFORE calling _get_sfreq which would trigger sequential downloads
#     158         if self.preload_files and self.download:
# --> 159             self.prefetch_files(get_event_files = self.preload_event_file)
#     160
#     161         # Now we can safely get sfreq as files are already downloading/downloaded
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in prefetch_files(self, get_event_files)
#     199             for future in futures:
#     200                 try:
# --> 201                     future.result()
#     202                 except Exception as e:
#     203                     print(f"Error downloading a file: {e}")
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-2801660784.py in <cell line: 0>()
#       4 # For training, we'll use all sessions from Sherlock 1 to Sherlock 5
#       5 train_run_keys = [("0",str(i),f"Sherlock{j}","1") for j in range(1,5) for i in range(1, num_chapters[j-1])]
# ----> 6 train_data = LibriBrainSpeech(
#       7   data_path=f"{base_path}/data/",
#       8   include_run_keys = train_run_keys,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/speech_dataset.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, oversample_silence_jitter, preload_files, stride, download)
#      97             Labels are arrays indicating speech (1) vs silence (0) for each timepoint in the sample.
#      98         """
# ---> 99         super().__init__(
#     100             data_path=data_path,
#     101             partition=partition,
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in __init__(self, data_path, partition, preprocessing_str, tmin, tmax, include_run_keys, exclude_run_keys, exclude_tasks, standardize, clipping_boundary, channel_means, channel_stds, include_info, preload_files, preload_event_file, download)
#     157         # Preload files if requested BEFORE calling _get_sfreq which would trigger sequential downloads
#     158         if self.preload_files and self.download:
# --> 159             self.prefetch_files(get_event_files = self.preload_event_file)
#     160
#     161         # Now we can safely get sfreq as files are already downloading/downloaded
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in prefetch_files(self, get_event_files)
#     199             for future in futures:
#     200                 try:
# --> 201                     future.result()
#     202                 except Exception as e:
#     203                     print(f"Error downloading a file: {e}")
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.12/concurrent/futures/thread.py in run(self)
#      57
#      58         try:
# ---> 59             result = self.fn(*self.args, **self.kwargs)
#      60         except BaseException as exc:
#      61             self.future.set_exception(exc)
#
# /usr/local/lib/python3.12/dist-packages/pnpl/datasets/libribrain2025/base.py in _download_with_retry_static(fpath, rel_path, data_path, max_retries)
#     334                         download_kwargs["token"] = repo_config["token"]
#     335
# --> 336                     return hf_hub_download(**download_kwargs)
#     337
#     338                 except (RepositoryNotFoundError, EntryNotFoundError, GatedRepoError) as e:
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     985             )
#     986
# --> 987         return _hf_hub_download_to_local_dir(
#     988             # Destination
#     989             local_dir=local_dir,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_local_dir(local_dir, repo_id, repo_type, filename, revision, endpoint, etag_timeout, headers, proxies, token, cache_dir, force_download, local_files_only)
#    1295     with WeakFileLock(paths.lock_path):
#    1296         paths.file_path.unlink(missing_ok=True)  # delete outdated file first
# -> 1297         _download_to_tmp_and_move(
#    1298             incomplete_path=paths.incomplete_path(etag),
#    1299             destination_path=paths.file_path,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1718         if xet_file_data is not None and is_xet_available():
#    1719             logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1720             xet_get(
#    1721                 incomplete_path=incomplete_path,
#    1722                 xet_file_data=xet_file_data,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624             progress.update(progress_bytes)
#     625
# --> 626         download_files(
#     627             xet_download_info,
#     628             endpoint=connection_info.endpoint,
#
# KeyboardInterrupt:

# %%
# For validation, we'll use all sessions from Sherlock 6
val_data = LibriBrainSpeech(
  data_path=f"{base_path}/data/",
  include_run_keys=[("0",i,"Sherlock6","1") for i in range(1, num_chapters[5])],
  standardize=True,
  tmin=0.0,
  tmax=0.8,
  preload_files = True
)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False, num_workers=num_workers)


# For testing, we'll use all sessions from Sherlock 7
test_data = LibriBrainSpeech(
  data_path=f"{base_path}/data/",
  include_run_keys=[("0",i,"Sherlock7","1") for i in range(1, num_chapters[6])],
  standardize=True,
  tmin=0.0,
  tmax=0.8,
  preload_files = True
)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False, num_workers=num_workers)


print("Number of training samples:", len(train_data))
print("Number of validation samples:", len(val_data))
print("Number of test samples:", len(test_data))
